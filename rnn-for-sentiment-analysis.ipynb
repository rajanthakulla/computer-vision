# %%
import tensorflow as tf
from tensorflow.keras import layers

# %%
# Load dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.imdb.load_data(num_words=10000)
x_train = tf.keras.preprocessing.sequence.pad_sequences(x_train, maxlen=200)
x_test = tf.keras.preprocessing.sequence.pad_sequences(x_test, maxlen=200)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 52s 3us/step

# %%
# Build RNN
model = tf.keras.Sequential([
    layers.Embedding(10000, 32),
    layers.SimpleRNN(64),
    layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=5, batch_size=64, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 31s 73ms/step - accuracy: 0.8760 - loss: 0.3030 - val_accuracy: 0.8140 - val_loss: 0.4516
# Epoch 2/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 71ms/step - accuracy: 0.9055 - loss: 0.2469 - val_accuracy: 0.8073 - val_loss: 0.4833
# Epoch 3/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 67ms/step - accuracy: 0.8780 - loss: 0.3041 - val_accuracy: 0.8126 - val_loss: 0.4691
# Epoch 4/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 68ms/step - accuracy: 0.8009 - loss: 0.4096 - val_accuracy: 0.7087 - val_loss: 0.6018
# Epoch 5/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 67ms/step - accuracy: 0.8807 - loss: 0.2909 - val_accuracy: 0.7875 - val_loss: 0.5280

# %%
print("Test Accuracy:", model.evaluate(x_test, y_test)[1])
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.7845 - loss: 0.5365
# Test Accuracy: 0.7874799966812134
